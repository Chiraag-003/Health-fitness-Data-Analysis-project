# %%
import pandas as pd

df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")
df = df.loc[:, ~df.columns.str.contains("Unnamed")]
df["health_risk_flag"] = ((df["blood_pressure_systolic"] > 140) |(df["bmi"] > 30) |(df["resting_heart_rate"] > 90)).map({True: "High Risk", False: "Normal"})
df["activity_consistency"] = df["duration_minutes"] / df["duration_minutes"].mean()

df["activity_consistency_type"] = df["activity_consistency"].apply(
    lambda x: "Consistent" if x >= 1 else "Inconsistent"
)
df["recovery_quality"] = (
    (df["hours_sleep"] >= 7) &
    (df["stress_level"] <= 5)
).map({True: "Good Recovery", False: "Poor Recovery"})
def lifestyle_balance(row):
    score = 0
    
    if row["daily_steps"] >= 8000:
        score += 1
    if row["hours_sleep"] >= 7:
        score += 1
    if row["hydration_level"] >= 2:
        score += 1
    if row["stress_level"] <= 5:
        score += 1

    if score >= 3:
        return "Balanced"
    elif score == 2:
        return "Moderate"
    else:
        return "Imbalanced"

df["lifestyle_balance"] = df.apply(lifestyle_balance, axis=1)
df["fitness_readiness"] = (
    (df["fitness_level"].isin(["Intermediate", "Advanced"])) &
    (df["health_risk_flag"] == "Normal") &
    (df["recovery_quality"] == "Good Recovery")
).map({True: "Ready", False: "Not Ready"})
df[
    [
        "health_risk_flag",
        "activity_consistency_type",
        "recovery_quality",
        "lifestyle_balance",
        "fitness_readiness"
    ]
].head(20)
df[
    [
        "blood_pressure_systolic",
        "bmi",
        "resting_heart_rate",
        "health_risk_flag"
    ]
].head(20)
df["activity_consistency"] = (
    df["duration_minutes"] / df["duration_minutes"].mean()
)
df["activity_consistency_type"] = df["activity_consistency"].apply(
    lambda x: "Consistent" if x >= 1 else "Inconsistent"
)
df[
    [
        "duration_minutes",
        "activity_consistency",
        "activity_consistency_type"
    ]
].head(20)
df["recovery_quality"] = (
    (df["hours_sleep"] >= 7) &
    (df["stress_level"] <= 5)
).map({True: "Good Recovery", False: "Poor Recovery"})
df[
    [
        "hours_sleep",
        "stress_level",
        "recovery_quality"
    ]
].head(20)
def lifestyle_balance(row):
    score = 0

    if row["daily_steps"] >= 8000:
        score += 1
    if row["hours_sleep"] >= 7:
        score += 1
    if row["hydration_level"] >= 2:
        score += 1
    if row["stress_level"] <= 5:
        score += 1

    if score >= 3:
        return "Balanced"
    elif score == 2:
        return "Moderate"
    else:
        return "Imbalanced"

df["lifestyle_balance"] = df.apply(lifestyle_balance, axis=1)
df[
    [
        "daily_steps",
        "hours_sleep",
        "hydration_level",
        "stress_level",
        "lifestyle_balance"
    ]
].head(20)
df["fitness_readiness"] = (
    (df["fitness_level"].isin(["Intermediate", "Advanced"])) &
    (df["recovery_quality"] == "Good Recovery") &
    (df["health_risk_flag"] == "Normal")
).map({True: "Ready", False: "Not Ready"})
df[
    [
        "fitness_level",
        "health_risk_flag",
        "recovery_quality",
        "fitness_readiness"
    ]
].head(20)
df.columns
df["recovery_quality"] = (
    (df["hours_sleep"] >= 7) &
    (df["stress_level"] <= 5)
).map({True: "Good Recovery", False: "Poor Recovery"})
df[
    [
        "hours_sleep",
        "stress_level",
        "recovery_quality"
    ]
].head(20)
df.columns

df["fitness_readiness"].value_counts()
final_features = df[
    [
        "participant_id",
        "health_risk_flag",
        "activity_consistency_type",
        "recovery_quality",
        "lifestyle_balance",
        "fitness_readiness"
    ]
]
feature_explanations = pd.DataFrame({
    "Feature Name": [
        "health_risk_flag",
        "activity_consistency_type",
        "recovery_quality",
        "lifestyle_balance",
        "fitness_readiness"
    ],
    "Why It Exists": [
        "Compresses multiple health vitals into a single screening signal",
        "Captures behavioral discipline relative to population average",
        "Measures whether the body is recovering adequately",
        "Summarizes overall lifestyle health into one interpretable score",
        "Provides an actionable decision for training readiness"
    ],
    "Business Question Answered": [
        "Is this person at potential health risk?",
        "Is the person consistently active or irregular?",
        "Is the person recovering well enough to sustain performance?",
        "How balanced is this person’s lifestyle overall?",
        "Is this person ready for higher-intensity recommendations?"
    ]
})
feature_explanations
feature_explanations.to_excel("Day60_feature_explanation_sheet.xlsx",
index=False)
final_features.columns
# Out:
# Index(['participant_id', 'health_risk_flag', 'activity_consistency_type',
#        'recovery_quality', 'lifestyle_balance', 'fitness_readiness'],
#       dtype='object')

# %%
import pandas as pd

df = pd.read_excel = (r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")
feature_explanations = pd.DataFrame({
    "Feature Name": [
        "health_risk_flag",
        "activity_consistency_type",
        "recovery_quality",
        "lifestyle_balance",
        "fitness_readiness"
    ],
    "Why It Exists": [
        "Compresses multiple health vitals into a single screening signal",
        "Captures behavioral discipline relative to population average",
        "Measures whether the body is recovering adequately",
        "Summarizes overall lifestyle health into one interpretable score",
        "Provides an actionable decision for training readiness"
    ],
    "Business Question Answered": [
        "Is this person at potential health risk?",
        "Is the person consistently active or irregular?",
        "Is the person recovering well enough to sustain performance?",
        "How balanced is this person’s lifestyle overall?",
        "Is this person ready for higher-intensity recommendations?"
    ]
})
feature_explanations
feature_explanations.to_excel("Day60_feature_explanation_sheet.xlsx",
index=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")


analysis_df = df[
    [
        "hours_sleep",
        "daily_steps",
        "hydration_level",
        "stress_level",
        "blood_pressure_systolic",
        "bmi",
        "resting_heart_rate"
    ]
]


correlation_matrix = analysis_df.corr()


plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Health & Lifestyle Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 5 df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")
#       8 analysis_df = df[
#       9     [
#      10         "hours_sleep",
#    (...)     17     ]
#      18 ]
#      21 correlation_matrix = analysis_df.corr()
#
# TypeError: 'str' object is not callable

# %%
sns.pairplot(
    df[
        [
            "hours_sleep",
            "daily_steps",
            "hydration_level",
            "stress_level"
        ]
    ]
)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")

df = df.loc[:, ~df.columns.str.contains("Unnamed")]

df["recovery_quality"] = (
    (df["hours_sleep"] >= 7) &
    (df["stress_level"] <= 5)
).map({True: "Good Recovery", False: "Poor Recovery"})

df["health_risk_flag"] = (
    (df["blood_pressure_systolic"] > 140) |
    (df["bmi"] > 30) |
    (df["resting_heart_rate"] > 90)
).map({True: "High Risk", False: "Normal"})

df["activity_segment"] = df["daily_steps"].apply(
    lambda x: "High Activity" if x >= 10000 else "Low Activity"
)

df["recovery_segment"] = df["recovery_quality"].apply(
    lambda x: "Low Recovery" if x == "Poor Recovery" else "Good Recovery"
)

df["risk_segment"] = df["health_risk_flag"].apply(
    lambda x: "High Risk" if x == "High Risk" else "Normal Risk"
)

print(df["activity_segment"].value_counts())
print(df["recovery_segment"].value_counts())
print(df["risk_segment"].value_counts())

plt.figure(figsize=(8,5))
sns.countplot(x="activity_segment", data=df)
plt.title("User Activity Segments")
plt.show()

plt.figure(figsize=(8,5))
sns.countplot(x="recovery_segment", data=df)
plt.title("Recovery Segments")
plt.show()

plt.figure(figsize=(8,5))
sns.countplot(x="risk_segment", data=df)
plt.title("Health Risk Segments")
plt.show()
df.columns
# Out:
# activity_segment
# Low Activity     512917
# High Activity    174783
# Name: count, dtype: int64
# recovery_segment
# Low Recovery     641234
# Good Recovery     46466
# Name: count, dtype: int64
# risk_segment
# Normal Risk    687617
# High Risk          83
# Name: count, dtype: int64
# Index(['participant_id', 'date', 'age', 'gender', 'height_cm', 'weight_kg',
#        'activity_type', 'duration_minutes', 'Intensity_Type',
#        'calories_burned', 'avg_heart_rate', 'hours_sleep', 'Sleep_Type',
#        'stress_level', 'Stress_Type', 'daily_steps', 'Steps_type',
#        'hydration_level', 'bmi', 'resting_heart_rate',
#        'blood_pressure_systolic', 'blood_pressure_diastolic',
#        'health_condition', 'smoking_status', 'fitness_level',
#        'Fitness_cateogry ', 'recovery_quality', 'health_risk_flag',
#        'activity_segment', 'recovery_segment', 'risk_segment'],
#       dtype='object')

# %%
import pandas as pd

df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")

df = df.loc[:, ~df.columns.str.contains("Unnamed")]

df["activity_cohort"] = pd.cut(
    df["daily_steps"],
    bins=[0, 5000, 10000, 20000],
    labels=["Low Activity", "Moderate Activity", "High Activity"]
)

df["sleep_cohort"] = pd.cut(
    df["hours_sleep"],
    bins=[0, 6, 8, 12],
    labels=["Poor Sleep", "Normal Sleep", "Good Sleep"]
)

df["stress_cohort"] = pd.cut(
    df["stress_level"],
    bins=[0, 3, 6, 10],
    labels=["Low Stress", "Moderate Stress", "High Stress"]
)

cohort_table = df.groupby(
    ["activity_cohort", "sleep_cohort", "stress_cohort"]
).size().reset_index(name="user_count")

print(cohort_table.head(20))

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.countplot(x="activity_cohort", data=df)
plt.title("User Activity Cohorts")
plt.show()

plt.figure(figsize=(8,5))
sns.countplot(x="sleep_cohort", data=df)
plt.title("User Sleep Cohorts")
plt.show()

plt.figure(figsize=(8,5))
sns.countplot(x="stress_cohort", data=df)
plt.title("User Stress Cohorts")
plt.show()
# Out:
# C:\Users\CHIRU\AppData\Local\Temp\ipykernel_32252\2112536804.py:25: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cohort_table = df.groupby(
#       activity_cohort  sleep_cohort    stress_cohort  user_count
# 0        Low Activity    Poor Sleep       Low Stress       24756
# 1        Low Activity    Poor Sleep  Moderate Stress           0
# 2        Low Activity    Poor Sleep      High Stress           0
# 3        Low Activity  Normal Sleep       Low Stress           0
# 4        Low Activity  Normal Sleep  Moderate Stress           0
# 5        Low Activity  Normal Sleep      High Stress           0
# 6        Low Activity    Good Sleep       Low Stress           0
# 7        Low Activity    Good Sleep  Moderate Stress           0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")

df = df.loc[:, ~df.columns.str.contains("Unnamed")]

highest_stress_users = df.sort_values(by="stress_level", ascending=False).head(10)
lowest_sleep_users = df.sort_values(by="hours_sleep", ascending=True).head(10)
extreme_bmi_users = df.sort_values(by="bmi", ascending=False).head(10)

print("Highest Stress Users")
print(highest_stress_users[["participant_id","stress_level","hours_sleep","daily_steps","bmi"]])

missing_ids = highest_stress_users["participant_id"].isna().sum()
print(f"\nMissing participant_id in highest stress users: {missing_ids}")

print("\nLowest Sleep Users")
print(lowest_sleep_users[["participant_id","hours_sleep","stress_level","daily_steps","bmi"]])

print("\nExtreme BMI Users")
print(extreme_bmi_users[["participant_id","bmi","stress_level","hours_sleep","daily_steps"]])

plt.figure(figsize=(6,4))
sns.boxplot(x=df["stress_level"])
plt.title("Stress Level Outliers")
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x=df["hours_sleep"])
plt.title("Sleep Duration Outliers")
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x=df["bmi"])
plt.title("BMI Outliers")
plt.show()
# Out:
# Highest Stress Users
#         participant_id  stress_level  hours_sleep  daily_steps  bmi
# 687698             NaN          10.0         10.0      17241.0  NaN
# 687697             NaN          10.0         10.0      16864.0  NaN
# 687681             NaN          10.0         10.0      16407.0  NaN
# 687680             NaN          10.0         10.0      16371.0  NaN
# 687692             NaN          10.0         10.0      16696.0  NaN
# 687691             NaN          10.0         10.0      16689.0  NaN
# 687690             NaN          10.0         10.0      16639.0  NaN
# 687689             NaN          10.0         10.0      16601.0  NaN
# 687688             NaN          10.0         10.0      16555.0  NaN
# 687687             NaN          10.0         10.0      16500.0  NaN
#
# Missing participant_id in highest stress users: 10
#
# Lowest Sleep Users
#    participant_id  hours_sleep  stress_level  daily_steps   bmi
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")

df = df.loc[:, ~df.columns.str.contains("Unnamed")]

df["date"] = pd.to_datetime(df["date"])

df = df.sort_values(by="date")

daily_data = df.groupby("date")[["daily_steps","hours_sleep","stress_level"]].mean().reset_index()

daily_data["steps_rolling"] = daily_data["daily_steps"].rolling(window=7).mean()
daily_data["sleep_rolling"] = daily_data["hours_sleep"].rolling(window=7).mean()
daily_data["stress_rolling"] = daily_data["stress_level"].rolling(window=7).mean()

plt.figure(figsize=(8,4))
plt.plot(daily_data["date"], daily_data["daily_steps"])
plt.plot(daily_data["date"], daily_data["steps_rolling"])
plt.title("Steps Trend (with Rolling Average)")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(8,4))
plt.plot(daily_data["date"], daily_data["hours_sleep"])
plt.plot(daily_data["date"], daily_data["sleep_rolling"])
plt.title("Sleep Trend (with Rolling Average)")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(8,4))
plt.plot(daily_data["date"], daily_data["stress_level"])
plt.plot(daily_data["date"], daily_data["stress_rolling"])
plt.title("Stress Trend (with Rolling Average)")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")

df = df.loc[:, ~df.columns.str.contains("Unnamed")]

df = df.dropna(subset=["daily_steps","hours_sleep","stress_level","hydration_level","calories_burned","duration_minutes"])

df["daily_steps"] = df["daily_steps"].clip(0, 15000)
df["hours_sleep"] = df["hours_sleep"].clip(0, 8)
df["stress_level"] = df["stress_level"].clip(0, 10)
df["hydration_level"] = df["hydration_level"].clip(0, 4)

df["wellness_score"] = (
    (df["daily_steps"] / 15000) * 25 +
    (df["hours_sleep"] / 8) * 25 +
    (1 - (df["stress_level"] / 10)) * 25 +
    (df["hydration_level"] / 4) * 25
)

df["recovery_index"] = (
    (df["hours_sleep"] / 8) * 50 +
    (1 - (df["stress_level"] / 10)) * 50
)

df["activity_efficiency"] = df["calories_burned"] / df["duration_minutes"]

df["wellness_category"] = df["wellness_score"].apply(
    lambda x: "High" if x >= 75 else "Moderate" if x >= 50 else "Low"
)

df["recovery_category"] = df["recovery_index"].apply(
    lambda x: "Good" if x >= 70 else "Average" if x >= 40 else "Poor"
)

print(df[[
    "participant_id",
    "wellness_score",
    "wellness_category",
    "recovery_index",
    "recovery_category",
    "activity_efficiency"
]].head(10))

print("\nWellness Category Distribution:")
print(df["wellness_category"].value_counts())

print("\nRecovery Category Distribution:")
print(df["recovery_category"].value_counts())
# Out:
#    participant_id  wellness_score wellness_category  recovery_index  \
# 0             1.0       44.375000               Low            70.0
# 1             2.0       44.375000               Low            70.0
# 2             3.0       44.435000               Low            70.0
# 3             4.0       44.756667               Low            70.0
# 4             5.0       44.950000               Low            70.0
# 5             7.0       45.161667               Low            70.0
# 6             8.0       45.338333               Low            70.0
# 7             9.0       45.390000               Low            70.0
# 8            10.0       45.531667               Low            70.0
# 9            12.0       45.993333               Low            70.0
#
#   recovery_category  activity_efficiency
# 0              Good                0.040
# 1              Good                0.040
# 2              Good                0.040
# 3              Good                0.040
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel(r"G:\Datasets file\health_fitness_cleaned_dataset(AutoRecovered).xlsx")

df = df.loc[:, ~df.columns.str.contains("Unnamed")]


plt.figure(figsize=(6,4))
plt.hist(df["daily_steps"], bins=30)
plt.title("Distribution of Daily Steps")
plt.xlabel("Steps")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(6,4))
plt.hist(df["hours_sleep"], bins=20)
plt.title("Distribution of Sleep Duration")
plt.xlabel("Hours Sleep")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(6,4))
plt.hist(df["stress_level"], bins=10)
plt.title("Distribution of Stress Level")
plt.xlabel("Stress Level")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(6,4))
plt.scatter(df["hours_sleep"], df["stress_level"])
plt.title("Sleep vs Stress Pattern")
plt.xlabel("Hours Sleep")
plt.ylabel("Stress Level")
plt.show()

plt.figure(figsize=(6,4))
plt.scatter(df["daily_steps"], df["calories_burned"])
plt.title("Steps vs Calories Burned")
plt.xlabel("Daily Steps")
plt.ylabel("Calories Burned")
plt.show()



df["date"] = pd.to_datetime(df["date"])
df = df.sort_values(by="date")

daily_data = df.groupby("date")[["daily_steps","hours_sleep","stress_level"]].mean().reset_index()

daily_data["steps_rolling"] = daily_data["daily_steps"].rolling(7).mean()

plt.figure(figsize=(8,4))
plt.plot(daily_data["date"], daily_data["daily_steps"])
plt.plot(daily_data["date"], daily_data["steps_rolling"])
plt.title("Steps Trend Story")
plt.xticks(rotation=45)
plt.show()
